# %% [markdown]
# # Curso de Testes Estatisitico Com Python

# %% [markdown]
# ## 1-Conhecendo os dados e explorando

# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as nb

# %% [markdown]
# ### tmdb

# %%
tmdb = pd.read_csv("./dados/tmdb_5000_movies.csv")
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
tmdb.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
ax = sns.displot(tmdb.vote_average, kde= True)
ax.set(xlabel = "Nota Média", ylabel="Quantidade de votos", title = "O grafico quantidade de votos x Notas")
ax.figure.set_size_inches(10,8)

# %%
ax = sns.displot(tmdb.vote_average, kind="kde")
ax.set(xlabel= 'Notas', ylabel="Densidade", title= 'Média de votos em filme no TMDB 5000')

# %%
ax = sns.boxplot(x=tmdb['vote_average'])
ax.set(xlabel = "Notas dos filmes", title= "Grafico de Caixa")
# Out:
# [Text(0.5, 0, 'Notas dos filmes'), Text(0.5, 1.0, 'Grafico de Caixa')]

# %%
tmdb.query("vote_average == 0").head(2)
# Out:
#       budget                                             genres  \
# 1464       0  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 3669       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
#
#                            homepage      id keywords original_language  \
# 1464                            NaN  310706       []                en
# 3669  http://www.romeothemovie.com/  113406       []                en
#
#             original_title                                           overview  \
# 1464   Black Water Transit  In this action thriller set in post-Katrina Ne...
# 3669  Should've Been Romeo  A self-centered, middle-aged pitchman for a po...
#
#       popularity                          production_companies  \
# 1464    0.126738        [{"name": "Capitol Films", "id": 826}]
# 3669    0.407030  [{"name": "Phillybrook Films", "id": 65147}]
#
#                                    production_countries release_date  revenue  \
# ...

# %%
tmdb.query("vote_average ==10")
# Out:
#       budget                                             genres homepage  \
# 3519       0                     [{"id": 35, "name": "Comedy"}]      NaN
# 4045       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...      NaN
# 4247       1  [{"id": 10749, "name": "Romance"}, {"id": 35, ...      NaN
# 4662       0                     [{"id": 35, "name": "Comedy"}]      NaN
#
#           id                                           keywords  \
# 3519   89861  [{"id": 131, "name": "italy"}, {"id": 8250, "n...
# 4045   78373  [{"id": 1415, "name": "small town"}, {"id": 15...
# 4247  361505                                                 []
# 4662   40963        [{"id": 10183, "name": "independent film"}]
#
#      original_language         original_title  \
# 3519                en       Stiff Upper Lips
# 4045                en  Dancer, Texas Pop. 81
# 4247                en  Me You and Five Bucks
# 4662                en         Little Big Top
#
# ...

# %%
tmdb_com_mais_de_10_votos = tmdb.query('vote_count >= 10')
tmdb_com_mais_de_10_votos.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.392000e+03    4392.000000  4392.000000  4.392000e+03  4391.000000
# mean   3.164545e+07   49204.119991    23.448815  8.990969e+07   108.430881
# std    4.162736e+07   80136.249777    32.592158  1.682870e+08    21.014719
# min    0.000000e+00       5.000000     0.011697  0.000000e+00     0.000000
# 25%    2.895962e+06    8403.500000     6.512166  1.365700e+04    95.000000
# 50%    1.700000e+07   13084.500000    14.827784  2.685837e+07   105.000000
# 75%    4.200000e+07   46831.250000    30.258282  1.022818e+08   118.500000
# max    3.800000e+08  417859.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4392.000000   4392.000000
# mean       6.226935    754.441712
# std        0.893215   1272.263761
# min        1.900000     10.000000
# 25%        5.700000     83.750000
# 50%        6.300000    288.500000
# 75%        6.800000    831.000000
# ...

# %%
ax = sns.histplot(tmdb_com_mais_de_10_votos.vote_average, kde=False)

ax.set_title('Média de votos em filmes no TMBD 5000')

plt.show()

# %%
ax = sns.displot(tmdb_com_mais_de_10_votos.vote_average, kde=True)

ax.set(xlabel='Nota média', ylabel='Densidade')
ax.fig.suptitle('Média de votos em filmes no TMBD 5000', y=1.02)


plt.show()

# %%
ax = sns.boxplot(x=tmdb_com_mais_de_10_votos['vote_average'])
ax.set(xlabel = "Notas dos filmes", title= "Titulo com mais de 10 votos")
# Out:
# [Text(0.5, 0, 'Notas dos filmes'),
#  Text(0.5, 1.0, 'Titulo com mais de 10 votos')]

# %% [markdown]
# ### Movielens

# %%
notas = pd.read_csv("./dados/ratings.csv")
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
nota_media_por_filme = notas.groupby("movieId").mean()["rating"]
nota_media_por_filme.head()
# Out:
# movieId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: rating, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.displot(nota_media_por_filme.values, kde=True,  stat="density")
plt.xlabel('Nota média')
plt.ylabel('Densidade')
plt.title('Média de votos em filmes no MovieLens')
plt.show()

# %%
quantidade_de_votos_por_filme = notas.groupby("movieId").count()
quantidade_de_votos_por_filme.query("rating >= 10")
# Out:
#          userId  rating  timestamp
# movieId
# 1           215     215        215
# 2           110     110        110
# 3            52      52         52
# 5            49      49         49
# 6           102     102        102
# ...         ...     ...        ...
# 174055       13      13         13
# 176371       18      18         18
# 177765       13      13         13
# 179819       12      12         12
# 187593       12      12         12
#
# [2269 rows x 3 columns]

# %%
quantidade_de_votos_por_filme = notas.groupby("movieId").count()
filmes_com_pelo_menos_10_votos = quantidade_de_votos_por_filme.query("rating >= 10").index

# %%
nota_media_dos_filmes_com_pelo_menos_10_votos = nota_media_por_filme.loc[filmes_com_pelo_menos_10_votos.values]
nota_media_dos_filmes_com_pelo_menos_10_votos.head()
# Out:
# movieId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 5    3.071429
# 6    3.946078
# Name: rating, dtype: float64

# %%
sns.histplot(nota_media_dos_filmes_com_pelo_menos_10_votos, kde=True, stat="density")
plt.xlabel('Nota média')
plt.ylabel('Densidade')
plt.title('Média de votos em filmes no MovieLens')
plt.show()

# %%
ax = sns.boxplot(x=nota_media_dos_filmes_com_pelo_menos_10_votos.values)
ax.set(xlabel='Nota  média do filme')
ax.set_title('Distribuição de nota média dos filmes do MovieLens')
plt.show()

# %% [markdown]
# ### CDF

# %%
ax = sns.histplot(nota_media_dos_filmes_com_pelo_menos_10_votos,cumulative=True, stat='density',kde=True)
ax.set(xlabel='Nota média', ylabel='Proporção acumulada de filmes')
ax.set_title('Média de votos em filmes no MovieLens')
plt.show()

# %%
ax = sns.histplot(tmdb_com_mais_de_10_votos.vote_average,cumulative=True, stat='density',kde=True)
ax.set(xlabel='Nota média', ylabel='Proporção acumulada de filmes')
ax.set_title('Média de votos em filmes no TMDB 5000')
plt.show()

# %% [markdown]
# ## 2-Explorando as distribuições das amostras

# %%
ax = sns.histplot(tmdb_com_mais_de_10_votos.vote_count, kde=True, stat='density')
ax.set(xlabel='Número de votos', ylabel='Densidade')
ax.set_title('Número de votos em filmes no TMDB 5000 com 10 ou mais votos')

plt.show()

# %%
tmdb_filtered = tmdb.query("budget > 0")
ax = sns.histplot(tmdb_filtered.budget, kde=True, stat='density')
ax.set(xlabel='Gastos', ylabel='Densidade')
ax.set_title('Gastos em filmes no TMDB 5000')
plt.show()

# %%
tmdb.query("popularity == 0")
# Out:
#       budget genres homepage      id keywords original_language  \
# 4553       0     []      NaN  380097       []                en
#
#                   original_title  \
# 4553  America Is Still the Place
#
#                                                overview  popularity  \
# 4553  1971 post civil rights San Francisco seemed li...         0.0
#
#      production_companies production_countries release_date  revenue  runtime  \
# 4553                   []                   []          NaN        0      0.0
#
#      spoken_languages    status tagline                       title  \
# 4553               []  Released     NaN  America Is Still the Place
#
#       vote_average  vote_count
# 4553           0.0           0

# %%
ax = sns.histplot(tmdb.popularity, kde=True, stat='density')
ax.set(xlabel='Popularidade', ylabel='Densidade')
ax.set_title('Popularidade dos filmes no TMDB 5000')
plt.show()

# %%
ax = sns.histplot(tmdb.runtime.dropna(), kde=True, stat='density')
ax.set(xlabel='Duração', ylabel='Densidade')
ax.set_title('Duração dos filmes no TMDB 5000')
plt.show()

# %%
tmdb_duracao_positiva = tmdb.query("runtime > 0")['runtime']
ax = sns.histplot(tmdb_duracao_positiva, kde=True, stat='density')
ax.set(xlabel='Tempo de duração', ylabel='Densidade')
ax.set_title('Duração dos filmes no TMDB 5000')
plt.show()

# %%
tmdb_duracao_positiva = tmdb.query("runtime > 0")['runtime']
ax = sns.histplot(tmdb_duracao_positiva, kde=True, stat='density', cumulative=True)
ax.set(xlabel='Tempo de duração', ylabel='Densidade')
ax.set_title('Duração dos filmes no TMDB 5000')
plt.show()

# %%
tmdb.query("runtime>0").runtime.dropna().quantile(q=0.8)
# Out:
# 121.0

# %% [markdown]
# ## 3-Teste de uma amostra

# %% [markdown]
# ### Efeito do tamanho de uma amostra

# %%
nota_media_dos_filmes_com_pelo_menos_10_votos.mean()
# Out:
# 3.4320503405352594

# %%
nota_media_dos_filmes_com_pelo_menos_10_votos[0:5].mean()
# Out:
# 3.5259741603585653

# %%
import matplotlib.pyplot as plt

medias = list()
for i in range(1, len(nota_media_dos_filmes_com_pelo_menos_10_votos)):
    medias.append(nota_media_dos_filmes_com_pelo_menos_10_votos[0:i].mean())
plt.plot(medias)

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(75243)
temp = nota_media_dos_filmes_com_pelo_menos_10_votos.sample(frac=1)

medias = list()
for i in range(1, len(temp)):
    medias.append(temp[0:i].mean())
plt.plot(medias)

# %%
np.random.seed(75243)
temp = nota_media_dos_filmes_com_pelo_menos_10_votos.sample(frac=1)

medias = list()
medias = [temp[0:i].mean() for i in range(1, len(temp))]

plt.plot(medias)

# %% [markdown]
# ### Intervalo de confiança da média com T e Z test

# %%
#https://vagas.ciadetalentos.com.br/hotsite/estagioazul2023?utm_source=EMKT&utm_medium=E-mail&utm_campaign=Azul_CT_Est%C3%A1gio_2023-1_Emkt_E-mail__28072023

# %%
from statsmodels.stats.weightstats import zconfint

zconfint(nota_media_dos_filmes_com_pelo_menos_10_votos)
# Out:
# (3.4112459477469557, 3.452854733323563)

# %%
from statsmodels.stats.weightstats import DescrStatsW

descr_todos_com_10_votos = DescrStatsW(nota_media_dos_filmes_com_pelo_menos_10_votos)
descr_todos_com_10_votos

# %%
descr_todos_com_10_votos.tconfint_mean()
# Out:
# (3.41123483922938, 3.4528658418411386)

# %% [markdown]
# ## 4-Outros testes

# %% [markdown]
# ### Ztest para uma amostra

# %%
filmes = pd.read_csv("./dados/movies.csv")
filmes.query("movieId == 1")
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy

# %%
notas1 = notas.query("movieId ==1")
notas1.head()
# Out:
#       userId  movieId  rating   timestamp
# 0          1        1     4.0   964982703
# 516        5        1     4.0   847434962
# 874        7        1     4.5  1106635946
# 1434      15        1     2.5  1510577970
# 1667      17        1     4.5  1305696483

# %%
ax = sns.histplot(notas1.rating,kde=True)
ax.set(xlabel='Notas do Toy Story', ylabel='Densidade')
ax.set_title('Distribuição das notas para o Toy Story')
plt.show()

# %%
ax = sns.boxplot(notas1.rating,orient="h",color = 'g')
ax.set(xlabel='Notas')
ax.set_title('Distribuição das notas para o Toy Story')
plt.show()

# %%
notas1.rating.mean()
# Out:
# 3.9209302325581397

# %%
notas1.rating.count()
# Out:
# 215

# %%
zconfint(notas1.rating)
# Out:
# (3.8093359183563402, 4.032524546759939)

# %%
from statsmodels.stats.weightstats import ztest

ztest(notas1.rating, value = 3.4320503405352603)
# Out:
# (8.586342305916716, 8.978190401886942e-18)

# %% [markdown]
# ### Problemas de amostras pequenas

# %%
np.random.seed(75241)
temp = notas1.sample(frac=1).rating

medias = [temp[0:i].mean() for i in range(1, len(temp))]

plt.plot(medias)

# %%
np.random.seed(75241)
temp = notas1.sample(frac=1).rating

def calcula_teste(i):
    media = temp[0:i].mean()
    stat, p = ztest(temp[0:i], value = 3.4320503405352603) 
    return (i,media, p)

valores = np.array([calcula_teste(i) for i in range(2, len(temp))])
plt.plot(valores[:,0],valores[:,1])
plt.plot(valores[:,0],valores[:,2])
plt.hlines(y = 0.05, xmin= 2, xmax= len(temp), colors='r')

# %% [markdown]
# ## 5-Testes para duas amostras

# %% [markdown]
# ###  Comparando a média de duas amostras

# %%
zconfint(notas1.rating, notas.rating)
# Out:
# (0.2799245129192442, 0.5588219849631111)

# %%
print (ztest(notas1.rating, notas.rating)) #Pvalues
zconfint(notas1.rating, notas.rating)
# Out:
# (5.894327101501841, 3.762112778881965e-09)
# (0.2799245129192442, 0.5588219849631111)

# %%
print (ztest(notas1.rating, notas.rating))
zconfint(notas.rating, notas1.rating)
# Out:
# (5.894327101501841, 3.762112778881965e-09)
# (-0.5588219849631111, -0.2799245129192442)

# %%
from scipy.stats import ttest_ind

ttest_ind(notas.rating, notas1.rating)
# Out:
# Ttest_indResult(statistic=-5.894327101501841, pvalue=3.774003138720876e-09)

# %%
descr_todas_as_notas = DescrStatsW(notas.rating)
descr_toystory = DescrStatsW(notas1.rating)
descr_todas_as_notas.get_compare(descr_toystory)

# %%
descr_todas_as_notas = DescrStatsW(notas.rating)
descr_toystory = DescrStatsW(notas1.rating)
comparacao = descr_todas_as_notas.get_compare(descr_toystory)

comparacao.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
import statsmodels as sm

# %%
descr_todas_as_notas = DescrStatsW(notas.rating)
descr_toystory = DescrStatsW(notas1.rating)
comparacao = descr_todas_as_notas.get_compare(descr_toystory)

comparacao.summary(use_t=True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ### Visualizando graficamente

# %%
plt.boxplot([notas.rating, notas1.rating], labels=["Todas as notas", "Toy Story"])
plt.title("Distribuição das notas de acordo com filmes")
plt.grid(True)

# %%
import matplotlib.pyplot as plt

plt.boxplot([notas.rating, notas1[3:12].rating], labels=["Todas as notas", "Toy Story (do 3 ao 12)"])
plt.title("Distribuição das notas de acordo com filmes")
plt.grid(True)

# %%
descr_todas_as_notas = DescrStatsW(notas.rating)
descr_toystory = DescrStatsW(notas1[3:12].rating)
comparacao = descr_todas_as_notas.get_compare(descr_toystory)

comparacao.summary(use_t=True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ## 6-Não Paramétricos

# %% [markdown]
# ### Comparando Filmes

# %%
notas1 =  notas.query("movieId == 1")
notas593 =  notas.query("movieId == 593")
notas72226 =  notas.query("movieId == 72226")

plt.boxplot([notas1.rating, notas593.rating, notas72226.rating], labels=["Toy Story", "Silence of the Lambs,", "Fantastic Mr. Fox"])
plt.title("Distribuição das notas de acordo com filmes")
# Out:
# Text(0.5, 1.0, 'Distribuição das notas de acordo com filmes')

# %%
sns.boxplot(x = "movieId", y = "rating", data = notas.query("movieId in (1, 593, 72226)"))
# Out:
# <Axes: xlabel='movieId', ylabel='rating'>

# %%
notas.query("movieId in (1,593,72226)").groupby("movieId").count()
# Out:
#          userId  rating  timestamp
# movieId
# 1           215     215        215
# 593         279     279        279
# 72226        18      18         18

# %%
descr_1 = DescrStatsW(notas1.rating)
descr_593 = DescrStatsW(notas593.rating)
comparacao = descr_1.get_compare(descr_593)

comparacao.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
descr_72226 = DescrStatsW(notas72226.rating)
descr_593 = DescrStatsW(notas593.rating)
comparacao = descr_72226.get_compare(descr_593)

comparacao.summary(use_t=True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
comparacao = descr_1.get_compare(descr_72226)

comparacao.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
notas.query("movieId in (1, 593, 72226)").groupby("movieId").count()
# Out:
#          userId  rating  timestamp
# movieId
# 1           215     215        215
# 593         279     279        279
# 72226        18      18         18

# %% [markdown]
# ### Comparação não parametrica

# %%
from scipy.stats import normaltest

stat, p = normaltest(notas1.rating)
p
# Out:
# 0.00011053430732728716

# %%
from scipy.stats import ranksums

_, p = ranksums(notas1.rating, notas593.rating)
p
# Out:
# 0.0003267718756440693
